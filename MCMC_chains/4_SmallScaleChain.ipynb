# %% [markdown]
# # Tutorial 4: Initializing a small-scale chain

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sys
sys.path.append('..')
from gstatsmcmc import Topography
from gstatsmcmc import MCMC
import gstatsim as gs
from sklearn.preprocessing import QuantileTransformer
import skgstat as skg

# %%
# load compiled bed elevation measurements
df = pd.read_csv('../data/BindSchalder_Macayeal_IceStreams.csv')
df.head
# Out:
# <bound method NDFrame.head of               x        y    surf  bed        velx        vely       smb  \
# 0       -997250 -1056750  1995.0  NaN    3.154910    3.089999  0.188461
# 1       -996750 -1056750  1991.0  NaN    2.865254    2.668077  0.187869
# 2       -996250 -1056750  1989.0  NaN    3.341836    3.024601  0.187278
# 3       -995750 -1056750  1988.0  NaN    3.897542    3.608380  0.186686
# 4       -995250 -1056750  1987.0  NaN    3.632191    3.761807  0.186094
# ...         ...      ...     ...  ...         ...         ...       ...
# 1193309 -410750  -550750   312.0  NaN  515.422234 -264.242581  0.067617
# 1193310 -410250  -550750   311.0  NaN  517.782817 -260.324541  0.067526
# 1193311 -409750  -550750   311.0  NaN  520.233378 -256.053416  0.067435
# 1193312 -409250  -550750   311.0  NaN  522.270657 -252.067006  0.067344
# 1193313 -408750  -550750   311.0  NaN  524.244480 -248.362956  0.067252
#
#              dhdt  highvel_mask  bedmap_mask  bedmap_surf  bedmachine_source  \
# 0        0.015527         False          1.0       1995.0                5.0
# 1        0.015527         False          1.0       1991.0                5.0
# 2        0.015527         False          1.0       1989.0                5.0
# 3        0.015527         False          1.0       1988.0                5.0
# 4        0.014805         False          1.0       1987.0                5.0
# ...           ...           ...          ...          ...                ...
# 1193309  0.199329          True          1.0        312.0                5.0
# 1193310  0.200631          True          1.0        311.0                5.0
# 1193311  0.201009          True          1.0        311.0                5.0
# 1193312  0.199707          True          1.0        311.0                5.0
# 1193313  0.198405          True          1.0        311.0                5.0
#
#          bedmachine_thickness  bedmap_bed
# 0                 2013.206726       -68.0
# 1                 2003.393005       -65.0
# 2                 1992.894836       -60.0
# 3                 1983.685974       -54.0
# 4                 1974.599670       -49.0
# ...                       ...         ...
# 1193309            943.046890      -654.0
# 1193310            941.342056      -648.0
# 1193311            940.834976      -642.0
# 1193312            939.315460      -637.0
# 1193313            936.297256      -632.0
#
# [1193314 rows x 14 columns]>

# %%
# create a grid of x and y coordinates
x_uniq = np.unique(df.x)
y_uniq = np.unique(df.y)

xmin = np.min(x_uniq)
xmax = np.max(x_uniq)
ymin = np.min(y_uniq)
ymax = np.max(y_uniq)

cols = len(x_uniq)
rows = len(y_uniq)

resolution = 500

xx, yy = np.meshgrid(x_uniq, y_uniq)

# %%
# load other data
dhdt = df['dhdt'].values.reshape(xx.shape)
smb = df['smb'].values.reshape(xx.shape)
velx = df['velx'].values.reshape(xx.shape)
vely = df['vely'].values.reshape(xx.shape)
bedmap_mask = df['bedmap_mask'].values.reshape(xx.shape)
bedmachine_thickness = df['bedmachine_thickness'].values.reshape(xx.shape)
bedmap_surf = df['bedmap_surf'].values.reshape(xx.shape)
highvel_mask = df['highvel_mask'].values.reshape(xx.shape)
bedmachine_bed = df['bedmap_surf'].values.reshape(xx.shape) - bedmachine_thickness
bedmap_bed = df['bedmap_bed'].values.reshape(xx.shape)

# %%
# create conditioning data
# bed elevation measurement in grounded ice region, and bedmachine bed topography elsewhere
cond_bed = np.where(bedmap_mask == 1, df['bed'].values.reshape(xx.shape), bedmap_bed)
df['cond_bed'] = cond_bed.flatten()
# create a mask of conditioning data
data_mask = ~np.isnan(cond_bed)

# %%
# normalize the conditioning bed data, saved to df['Nbed']
data = df['cond_bed'].values.reshape(-1,1)
nst_trans = QuantileTransformer(n_quantiles=500, output_distribution="normal",random_state=0).fit(data)
transformed_data = nst_trans.transform(data)
df['Nbed'] = transformed_data

# %%
# randomly drop out 50% of coordinates. Decrease this value if you have a lot of data and it takes a long time to run
df_sampled = df.sample(frac=0.15, random_state=42)
df_sampled = df_sampled[df_sampled["cond_bed"].isnull() == False]
df_sampled = df_sampled[df_sampled["bedmap_mask"]==1]

# compute experimental (isotropic) variogram
coords = df_sampled[['x','y']].values
values = df_sampled['cond_bed']

maxlag = 70000      # maximum range distance
n_lags = 30         # num of bins (try decreasing if this is taking too long)

# compute variogram
V1 = skg.Variogram(coords, values, bin_func='even', n_lags=n_lags, maxlag=maxlag, normalize=False, model='matern')

# extract variogram values
xdata = V1.bins
ydata = V1.experimental

V1_p = V1.parameters

# evaluate models
xi = np.linspace(0, xdata[-1], n_lags) 
y_mtn = [skg.models.matern(h, V1_p[0], V1_p[1], V1_p[2], V1_p[3]) for h in xi]
# variogram parameter is [range, sill, shape, nugget] for matern model.

plt.figure(figsize=(6,4))
plt.scatter(xdata, ydata, s=12, c='g')
plt.plot(xi, y_mtn,'b-.', label='Matern variogram model')
plt.title('Isotropic Experimental Variogram')
plt.xlabel('Lag (m)'); plt.ylabel('Semivariance')
plt.show()

# %%
V1_p
# Out:
# [51606.42030970357, 35588.66222256237, 0.4411693093985352, 0]

# %%
# load bed generated by Sequential Gaussian Simulation
sgs_bed = np.loadtxt('../2_Statistical_Analysis/sgs_bed_bindshalder.txt')
thickness = bedmap_surf - sgs_bed
sgs_bed = np.where((thickness<=0)&(bedmap_mask==1), bedmap_surf-1, sgs_bed)

# %% [markdown]
# ### Then initiating the SGS chain

# %% [markdown]
# The first 4 initialization process are very similar to chain_crf, please refers to Tutorial 3 for detailed information

# %%
grounded_ice_mask = (bedmap_mask == 1)

# %%
smallScaleChain = MCMC.chain_sgs(xx, yy, sgs_bed, bedmap_surf, velx, vely, dhdt, smb, cond_bed, data_mask, grounded_ice_mask, resolution)
# Out:
# before running the chain, please set where the block update will be using the object's function set_update_in_region(region_mask) and set_update_region(update_in_region)
# please also set up the sgs parameters using set_sgs_param(self, block_size, sgs_param)
# then please set up the loss function using either set_loss_type or set_loss_func

# %%
smallScaleChain.set_update_region(True,highvel_mask)
# Out:
# the update blocks is set to be randomly generated for any locations inside the given region

# %%
smallScaleChain.set_loss_type(map_func='sumsquare', sigma_mc=5, massConvInRegion=True)

# %%
# set up the block sizes
min_block_x = 5
max_block_x = 20
min_block_y = 5
max_block_y = 20
smallScaleChain.set_block_sizes(min_block_x, max_block_x, min_block_y, max_block_y)

# %% [markdown]
# Sequential Gaussian Simulation is set to perform on the normalized data. This nst_trans is an object of the QuantileTranformer class in scikit-learn python library. The *fit_variogram* function returns a nst_trans object, which could be directly used here

# %%
smallScaleChain.set_normal_transformation(nst_trans, do_transform=False)

# %% [markdown]
# When running the SGS chain, it is possible to 'detrend' the topography.
#
# Detrend topography refers to substracting a pre-defined trend from the topography map, where the trend suppose to represent long-wavelength features that violate stationary properties of SGS. If choose to detrend the topography, the argument *detrend_map* need to be set to True, and the argument *trend* need to be a 2D numpy array representing the topography trend

# %%
smallScaleChain.set_trend(trend = [], detrend_map = False)

# %%
smallScaleChain.set_variogram('Matern',V1_p[0],V1_p[1],0,isotropic=True,vario_smoothness=V1_p[2])
# Out:
# the variogram is set to type Matern

# %%
smallScaleChain.set_sgs_param(48, 50e3, sgs_rand_dropout_on=False)
# Out:
# because the sgs_rand_dropout_on is set to False, the dropout_rate is automatically set to 0

# %%
seed = 23034902
randomGenerator = np.random.default_rng(seed)

beds, loss_mc, loss_data, loss, steps, resampled_times, blocks_used = smallScaleChain.run(n_iter=5000, rng_seed=randomGenerator, only_save_last_bed=False, info_per_iter = 1000)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 4
#       1 seed = 23034902
#       2 randomGenerator = np.random.default_rng(seed)
# ----> 4 beds, loss_mc, loss_data, loss, steps, resampled_times, blocks_used = smallScaleChain.run(n_iter=5000, rng_seed=randomGenerator, only_save_last_bed=False, info_per_iter = 1000)
#
# File ~/Documents/Glaciers/MCMC_chains/../gstatsmcmc/MCMC.py:1214, in chain_sgs.run(self, n_iter, rng_seed, only_save_last_bed, info_per_iter)
#    1212 else:
#    1213     vario_p = self.vario_param[:6]
# -> 1214 sim2 = gs.Interpolation.okrige_sgs(Pred_grid_xy_change, new_df, 'x', 'y', 'z', self.sgs_param[0], vario_p, self.sgs_param[1], quiet=True, seed=rng)
#    1216 xy_grid = np.concatenate((Pred_grid_xy_change[:,0].reshape(-1,1),Pred_grid_xy_change[:,1].reshape(-1,1),np.array(sim2).reshape(-1,1)),axis=1)
#    1218 psimdf_next = psimdf.copy()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/gstatsmcmc/lib/python3.10/site-packages/gstatsim.py:1050, in Interpolation.okrige_sgs(prediction_grid, df, xx, yy, zz, num_points, vario, radius, seed, quiet)
#    1045 test_idx = np.sum(prediction_grid[z]==df[['X', 'Y']].values,axis = 1)
#    1046 if np.sum(test_idx==2)==0:
#    1047
#    1048     # gather nearest neighbor points
#    1049     nearest = NearestNeighbor.nearest_neighbor_search(radius, num_points,
# -> 1050                                       prediction_grid[z], df[['X','Y','Z']])
#    1051     norm_data_val = nearest[:,-1]
#    1052     xy_val = nearest[:,:-1]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/gstatsmcmc/lib/python3.10/site-packages/pandas/core/frame.py:4128, in DataFrame.__getitem__(self, key)
#    4125 if isinstance(indexer, slice):
#    4126     return self._slice(indexer, axis=1)
# -> 4128 data = self._take_with_is_copy(indexer, axis=1)
#    4130 if is_single_key:
#    4131     # What does looking for a single key in a non-unique index return?
#    4132     # The behavior is inconsistent. It returns a Series, except when
#    4133     # - the key itself is repeated (test on data.shape, #9519), or
#    4134     # - we have a MultiIndex on columns (test on self.columns, #21309)
#    4135     if data.shape[1] == 1 and not isinstance(self.columns, MultiIndex):
#    4136         # GH#26490 using data[key] can cause RecursionError
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/gstatsmcmc/lib/python3.10/site-packages/pandas/core/generic.py:4175, in NDFrame._take_with_is_copy(self, indices, axis)
#    4164 @final
#    4165 def _take_with_is_copy(self, indices, axis: Axis = 0) -> Self:
#    4166     """
#    4167     Internal version of the `take` method that sets the `_is_copy`
#    4168     attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    4173     See the docstring of `take` for full explanation of the parameters.
#    4174     """
# -> 4175     result = self.take(indices=indices, axis=axis)
#    4176     # Maybe set copy if we didn't actually change the index.
#    4177     if self.ndim == 2 and not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/gstatsmcmc/lib/python3.10/site-packages/pandas/core/generic.py:4155, in NDFrame.take(self, indices, axis, **kwargs)
#    4150     # We can get here with a slice via DataFrame.__getitem__
#    4151     indices = np.arange(
#    4152         indices.start, indices.stop, indices.step, dtype=np.intp
#    4153     )
# -> 4155 new_data = self._mgr.take(
#    4156     indices,
#    4157     axis=self._get_block_manager_axis(axis),
#    4158     verify=True,
#    4159 )
#    4160 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4161     self, method="take"
#    4162 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/gstatsmcmc/lib/python3.10/site-packages/pandas/core/internals/managers.py:913, in BaseBlockManager.take(self, indexer, axis, verify)
#     910 indexer = maybe_convert_indices(indexer, n, verify=verify)
#     912 new_labels = self.axes[axis].take(indexer)
# --> 913 return self.reindex_indexer(
#     914     new_axis=new_labels,
#     915     indexer=indexer,
#     916     axis=axis,
#     917     allow_dups=True,
#     918     copy=None,
#     919 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/gstatsmcmc/lib/python3.10/site-packages/pandas/core/internals/managers.py:699, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     696     raise IndexError("Requested axis not found in manager")
#     698 if axis == 0:
# --> 699     new_blocks = self._slice_take_blocks_ax0(
#     700         indexer,
#     701         fill_value=fill_value,
#     702         only_slice=only_slice,
#     703         use_na_proxy=use_na_proxy,
#     704     )
#     705 else:
#     706     new_blocks = [
#     707         blk.take_nd(
#     708             indexer,
#    (...)
#     714         for blk in self.blocks
#     715     ]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/gstatsmcmc/lib/python3.10/site-packages/pandas/core/internals/managers.py:862, in BaseBlockManager._slice_take_blocks_ax0(self, slice_or_indexer, fill_value, only_slice, use_na_proxy, ref_inplace_op)
#     860                     blocks.append(nb)
#     861             else:
# --> 862                 nb = blk.take_nd(taker, axis=0, new_mgr_locs=mgr_locs)
#     863                 blocks.append(nb)
#     865 return blocks
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/gstatsmcmc/lib/python3.10/site-packages/pandas/core/internals/blocks.py:1373, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1370     allow_fill = True
#    1372 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1373 new_values = algos.take_nd(
#    1374     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1375 )
#    1377 # Called from three places in managers, all of which satisfy
#    1378 #  these assertions
#    1379 if isinstance(self, ExtensionBlock):
#    1380     # NB: in this case, the 'axis' kwarg will be ignored in the
#    1381     #  algos.take_nd call above.
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/gstatsmcmc/lib/python3.10/site-packages/pandas/core/array_algos/take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/gstatsmcmc/lib/python3.10/site-packages/pandas/core/array_algos/take.py:162, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     157     out = np.empty(out_shape, dtype=dtype)
#     159 func = _get_take_nd_function(
#     160     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     161 )
# --> 162 func(arr, indexer, out, fill_value)
#     164 if flip_order:
#     165     out = out.T
#
# KeyboardInterrupt:

# %%
beds.shape

# %%
plt.pcolormesh(xx,yy,beds[0],vmax=2000,vmin=-2500)
plt.axis('scaled')
plt.colorbar()
plt.xlabel('x (m)')
plt.ylabel('y (m)')

# %%
plt.pcolormesh(xx,yy,beds[-1],vmax=2000,vmin=-2500)
plt.axis('scaled')
plt.colorbar()
plt.xlabel('x (m)')
plt.ylabel('y (m)')

# %%
plt.pcolormesh(xx,yy,beds[-1]-beds[0], cmap='RdBu',vmax=200,vmin=-200)
plt.axis('scaled')
plt.colorbar()
plt.xlabel('x (m)')
plt.ylabel('y (m)')
