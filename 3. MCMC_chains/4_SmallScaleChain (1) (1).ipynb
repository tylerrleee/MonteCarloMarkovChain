# %% [markdown]
# # Tutorial 4: Initializing a small-scale chain

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from gstatsmcmc import Topography
from gstatsmcmc import MCMC
import gstatsim as gs
from sklearn.preprocessing import QuantileTransformer
import skgstat as skg
import config

# %%
# load compiled bed elevation measurements
df = pd.read_csv('./BindSchalder_Macayeal_IceStreams.csv')

# %%
# create a grid of x and y coordinates
x_uniq = np.unique(df.x)
y_uniq = np.unique(df.y)

xmin = np.min(x_uniq)
xmax = np.max(x_uniq)
ymin = np.min(y_uniq)
ymax = np.max(y_uniq)

cols = len(x_uniq)
rows = len(y_uniq)

resolution = 500

xx, yy = np.meshgrid(x_uniq, y_uniq)

# %%
# load other data
dhdt = df['dhdt'].values.reshape(xx.shape)
smb = df['smb'].values.reshape(xx.shape)
velx = df['velx'].values.reshape(xx.shape)
vely = df['vely'].values.reshape(xx.shape)
bedmap_mask = df['bedmap_mask'].values.reshape(xx.shape)
bedmachine_thickness = df['bedmachine_thickness'].values.reshape(xx.shape)
bedmap_surf = df['bedmap_surf'].values.reshape(xx.shape)
highvel_mask = df['highvel_mask'].values.reshape(xx.shape)
bedmachine_bed = df['bedmap_surf'].values.reshape(xx.shape) - bedmachine_thickness
bedmap_bed = df['bedmap_bed'].values.reshape(xx.shape)

# %%
# create conditioning data
# bed elevation measurement in grounded ice region, and bedmap topography elsewhere
cond_bed = np.where(bedmap_mask == 1, df['bed'].values.reshape(xx.shape), bedmap_bed)
df['cond_bed'] = cond_bed.flatten()
# create a mask of conditioning data
data_mask = ~np.isnan(cond_bed)

# %% [markdown]
# __step1: calculate the trend__

# %%
current_index = config.current_index
initial_bed = np.loadtxt(f'./SGS_realizations/{current_index}final_bed_largeCRF.txt')

# %%
import scipy as sp
trend = sp.ndimage.gaussian_filter(initial_bed, sigma=10)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4),gridspec_kw={'width_ratios': [1, 1.3]} )

axes[0].pcolormesh(xx, yy, initial_bed, vmax=1500,vmin=-3500)
axes[0].set_title('initial bed')
axes[0].set_aspect('equal')

bedfig = axes[1].pcolormesh(xx, yy, trend, vmax=1500,vmin=-3500)
axes[1].set_title('topography trend (smoothed initial bed)')
axes[1].set_aspect('equal')
fig.colorbar(bedfig, ax=axes[1])

# %% [markdown]
# __step2: calculate detrended variogram__

# %%
 ##################WHEN NO DETREND###################
 #normalize the conditioning bed data, saved to df['Nbed']
data = df['cond_bed'].values.reshape(-1,1) 
nst_trans = QuantileTransformer(n_quantiles=500, output_distribution="normal",random_state=0).fit(data)
transformed_data = nst_trans.transform(data)
df['Nbed'] = transformed_data

# %%
"""
# normalize the de-trended conditioning data, saved to df['Nbed_residual']
df['cond_bed_residual']=df['cond_bed'].values-trend.flatten()
data = df['cond_bed_residual'].values.reshape(-1,1)
nst_trans = QuantileTransformer(n_quantiles=500, output_distribution="normal",random_state=0).fit(data)
transformed_data = nst_trans.transform(data)
df['Nbed_residual'] = transformed_data

# %%
###################WHEN NO DETREND###################
df_sampled = df.sample(frac=0.2, random_state=42)
df_sampled = df_sampled[df_sampled["cond_bed"].isnull() == False]
df_sampled = df_sampled[df_sampled["bedmap_mask"]==1]
coords = df_sampled[['x','y']].values
values = df_sampled['Nbed']
"""
# randomly drop out 50% of coordinates. Decrease this value if you have a lot of data and it takes a long time to run
df_sampled = df.sample(frac=0.2, random_state=42)
df_sampled = df_sampled[df_sampled["cond_bed_residual"].isnull() == False]
df_sampled = df_sampled[df_sampled["bedmap_mask"]==1]

# compute experimental (isotropic) variogram
coords = df_sampled[['x','y']].values
values = df_sampled['Nbed_residual']
"""

maxlag = 100000      # maximum range distance
n_lags = 70         # num of bins (try decreasing if this is taking too long)

# compute variogram
V1 = skg.Variogram(coords, values, bin_func='even', n_lags=n_lags, maxlag=maxlag, normalize=False, model='matern')

# extract variogram values
xdata = V1.bins
ydata = V1.experimental

V1_p = V1.parameters

# evaluate models
xi = np.linspace(0, xdata[-1], n_lags) 
y_mtn = [skg.models.matern(h, V1_p[0], V1_p[1], V1_p[2], V1_p[3]) for h in xi]
# variogram parameter is [range, sill, shape, nugget] for matern model.

plt.figure(figsize=(6,4))
plt.scatter(xdata, ydata, s=12, c='g')
plt.plot(xi, y_mtn,'b-.', label='Matern variogram model')
plt.title('Isotropic Experimental Variogram')
plt.xlabel('Lag (m)'); plt.ylabel('Semivariance')
plt.show()

# %%
V1_p
# DEtrend Variogram
#V1_p = [8024.503954511463, 1.1750642901930541, 3.4475128792851653, 0]

# Non detrend Variogram parameters
# Out:
# [83862.14824405785, 0.8726545703546237, 0.38777317326480054, 0]

# %%
###################When load sgs-generated bed as initial bed###################
# load the initial bed, make sure no bed in grounded ice region is higher altitude than ice surface
#sgs_bed = np.loadtxt('sgs_bed_totten_cropped.txt')
#thickness = bedmap_surf - sgs_bed
#sgs_bed = np.where((thickness<=0)&(bedmap_mask==1), bedmap_surf-1, sgs_bed)

# %% [markdown]
# ### Then initiating the SGS chain

# %% [markdown]
# The first 4 initialization process are very similar to chain_crf, please refers to Tutorial 3 for detailed information

# %%
grounded_ice_mask = (bedmap_mask == 1)

# %% [markdown]
# step3: set up the chain
# - change initial bed
# - set normal transformation
# - set trend

# %%
###################When start with a sgs-generated bed###################
#smallScaleChain = MCMC.chain_sgs(xx, yy, sgs_bed, bedmap_surf, velx, vely, dhdt, smb, cond_bed, data_mask, grounded_ice_mask, resolution)

# %%
smallScaleChain = MCMC.chain_sgs(xx, yy, initial_bed, bedmap_surf, velx, vely, dhdt, smb, cond_bed, data_mask, grounded_ice_mask, resolution)
# Out:
# before running the chain, please set where the block update will be using the object's function set_update_in_region(region_mask) and set_update_region(update_in_region)
# please also set up the sgs parameters using set_sgs_param(self, block_size, sgs_param)
# then please set up the loss function using either set_loss_type or set_loss_func

# %%
smallScaleChain.set_update_region(True,highvel_mask)
# Out:
# the update blocks is set to be randomly generated for any locations inside the given region

# %%
smallScaleChain.set_loss_type(map_func='sumsquare', sigma_mc=10, massConvInRegion=True)

# %%
# set up the block sizes
min_block_x = 5
max_block_x = 20
min_block_y = 5
max_block_y = 20
smallScaleChain.set_block_sizes(min_block_x, max_block_x, min_block_y, max_block_y)

# %% [markdown]
# Sequential Gaussian Simulation is set to perform on the normalized data. This nst_trans is an object of the QuantileTranformer class in scikit-learn python library. The *fit_variogram* function returns a nst_trans object, which could be directly used here

# %%
###################When no normal score transformation###################
# do_transform could be set to true for both detrend and no detrend options
# recommend to set it to true
#smallScaleChain.set_normal_transformation(nst_trans, do_transform=False)

# %%
smallScaleChain.set_normal_transformation(nst_trans, do_transform=True)

# %% [markdown]
# When running the SGS chain, it is possible to 'detrend' the topography.
#
# Detrend topography refers to substracting a pre-defined trend from the topography map, where the trend suppose to represent long-wavelength features that violate stationary properties of SGS. If choose to detrend the topography, the argument *detrend_map* need to be set to True, and the argument *trend* need to be a 2D numpy array representing the topography trend

# %%
###################WHEN NO DETREND###################
#smallScaleChain.set_trend(trend = [], detrend_map = False)

# %%
smallScaleChain.set_trend(trend = trend, detrend_map = True)

# %%
smallScaleChain.set_variogram('Matern',V1_p[0],V1_p[1],0,isotropic=True,vario_smoothness=V1_p[2])
# Out:
# the variogram is set to type Matern

# %%
smallScaleChain.set_sgs_param(48, 30e3, sgs_rand_dropout_on=False)
# Out:
# because the sgs_rand_dropout_on is set to False, the dropout_rate is automatically set to 0

# %% [markdown]
# __step4: run the chain, check if the loss is correct__

# %%
# test the new sgs
beds, loss_mc, loss_data, loss, steps, resampled_times, blocks_used = smallScaleChain.run_newsgs(n_iter=10000, only_save_last_bed=True, info_per_iter = 100)
# Out:
# i: 0 mc loss: 1.065e+04 loss: 1.065e+04 acceptance rate: 0.0
# i: 100 mc loss: 1.065e+04 loss: 1.065e+04 acceptance rate: 0.0297029702970297
# i: 200 mc loss: 1.065e+04 loss: 1.065e+04 acceptance rate: 0.029850746268656716
# i: 300 mc loss: 1.065e+04 loss: 1.065e+04 acceptance rate: 0.026578073089700997
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 2
#       1 # test the new sgs
# ----> 2 beds, loss_mc, loss_data, loss, steps, resampled_times, blocks_used = smallScaleChain.run_newsgs(n_iter=10000, only_save_last_bed=True, info_per_iter = 100)
#
# File ~/MonteCarloMarkovChain/gstatsmcmc/MCMC.py:1753, in chain_sgs.run_newsgs(self, n_iter, rng_seed, only_save_last_bed, info_per_iter)
#    1751 sim_mask = np.full(self.xx.shape, False)
#    1752 sim_mask[bxmin:bxmax,bymin:bymax] = True
# -> 1753 newsim = sgs(self.xx, self.yy, bed_tosim, vario, rad, neighbors, sim_mask = sim_mask)
#    1755 if self.do_transform == True:
#    1756     bed_next = nst_trans.inverse_transform(newsim.reshape(-1,1)).reshape(rows,cols)
#
# File ~/MonteCarloMarkovChain/gstatsmcmc/MCMC.py:146, in sgs(xx, yy, grid, variogram, radius, num_points, ktype, sim_mask, quiet, stencil, rcond, seed)
#     144 # solve kriging equations
#     145 if ktype=='ok':
# --> 146     est, var = gsim._krige.ok_solve((xx[i,j], yy[i,j]), nearest, local_vario, rcond)
#     147 elif ktype=='sk':
#     148     est, var = gsim._krige.sk_solve((xx[i,j], yy[i,j]), nearest, local_vario, global_mean, rcond)
#
# File ~/MonteCarloMarkovChain/gstatsmcmc/gstatsim_custom/_krige.py:27, in ok_solve(sim_xy, nearest, vario, rcond, precompute)
#      25 # covariance between data
#      26 Sigma = np.zeros((n+1, n+1))
# ---> 27 Sigma[0:n,0:n] = make_sigma(xy_val, rotation_matrix, vario)
#      28 Sigma[n,0:n] = 1
#      29 Sigma[0:n,n] = 1
#
# File ~/MonteCarloMarkovChain/gstatsmcmc/gstatsim_custom/_krige.py:120, in make_sigma(coord, rotation_matrix, vario)
#     106 """
#     107 Make covariance matrix showing covariances between each pair of input coordinates
#     108
#    (...)
#     116     numpy.ndarray: nxn matrix of covariance between n points
#     117 """
#     119 norm_range = squareform(pdist(coord @ rotation_matrix))
# --> 120 Sigma = covmodels[vario['vtype'].lower()](norm_range, **vario)
#     122 return Sigma
#
# File ~/MonteCarloMarkovChain/gstatsmcmc/gstatsim_custom/covariance.py:20, in matern_cov_norm(norm_range, sill, nugget, s, **kwargs)
#      18 scale = 0.45246434*np.exp(-0.70449189*s)+1.7863836
#      19 norm_range[norm_range==0.0] = 1e-8
# ---> 20 c = (sill-nugget)*2/gamma(s)*np.power(scale*norm_range*np.sqrt(s), s)*kv(s, 2*scale*norm_range*np.sqrt(s))
#      21 c[np.isnan(c)] = sill-nugget
#      22 return c
#
# KeyboardInterrupt:

# %%
# test the original sgs
beds, loss_mc, loss_data, loss, steps, resampled_times, blocks_used = smallScaleChain.run_newsgs(n_iter=100, only_save_last_bed=True, info_per_iter = 1000)
# Out:
# i: 0 mc loss: 1.278e+06 loss: 1.278e+06 acceptance rate: 1.0

# %%
plt.pcolormesh(xx,yy,beds,vmax=1500,vmin=-1500)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 plt.pcolormesh(xx,yy,beds,vmax=1500,vmin=-1500)
#
# NameError: name 'beds' is not defined

# %%
n_iter = 10000

for i in range(0,20):
    beds, loss_mc, loss_data, loss, steps, resampled_times, blocks_used = smallScaleChain.run_newsgs(n_iter=n_iter, only_save_last_bed=True, info_per_iter = 200)
    
    # save all the data in every run of the algorithm
    np.savetxt('T4_loss'+str(i*n_iter)+'.txt', loss)
    np.savetxt('T4_steps'+str(i*n_iter)+'.txt', steps) 
    np.savetxt('T4_bed'+str(i*n_iter)+'.txt',beds)
    
    # set up the next chain
    smallScaleChain.initial_bed = beds
# Out:
# i: 0 mc loss: 1.065e+04 loss: 1.065e+04 acceptance rate: 0.0
# i: 200 mc loss: 1.065e+04 loss: 1.065e+04 acceptance rate: 0.009950248756218905
# i: 400 mc loss: 1.065e+04 loss: 1.065e+04 acceptance rate: 0.007481296758104738
# i: 600 mc loss: 1.065e+04 loss: 1.065e+04 acceptance rate: 0.009983361064891847
# i: 800 mc loss: 1.065e+04 loss: 1.065e+04 acceptance rate: 0.008739076154806492
# i: 1000 mc loss: 1.065e+04 loss: 1.065e+04 acceptance rate: 0.008991008991008992
# i: 1200 mc loss: 1.065e+04 loss: 1.065e+04 acceptance rate: 0.00749375520399667
# i: 1400 mc loss: 1.065e+04 loss: 1.065e+04 acceptance rate: 0.007137758743754461
# i: 1600 mc loss: 1.065e+04 loss: 1.065e+04 acceptance rate: 0.006870705808869456
# i: 1800 mc loss: 1.065e+04 loss: 1.065e+04 acceptance rate: 0.007218212104386452
# i: 2000 mc loss: 1.065e+04 loss: 1.065e+04 acceptance rate: 0.006496751624187906
# i: 2200 mc loss: 1.065e+04 loss: 1.065e+04 acceptance rate: 0.005906406179009541
# i: 2400 mc loss: 1.065e+04 loss: 1.065e+04 acceptance rate: 0.006247396917950854
# i: 2600 mc loss: 1.065e+04 loss: 1.065e+04 acceptance rate: 0.0057670126874279125
# i: 2800 mc loss: 1.066e+04 loss: 1.066e+04 acceptance rate: 0.006783291681542306
# i: 3000 mc loss: 1.066e+04 loss: 1.066e+04 acceptance rate: 0.007997334221926024
# i: 3200 mc loss: 1.066e+04 loss: 1.066e+04 acceptance rate: 0.008122461730709154
# i: 3400 mc loss: 1.066e+04 loss: 1.066e+04 acceptance rate: 0.007938841517200824
# i: 3600 mc loss: 1.066e+04 loss: 1.066e+04 acceptance rate: 0.007775617883921133
# i: 3800 mc loss: 1.066e+04 loss: 1.066e+04 acceptance rate: 0.008418837148118917
# i: 4000 mc loss: 1.066e+04 loss: 1.066e+04 acceptance rate: 0.008247938015496127
# i: 4200 mc loss: 1.066e+04 loss: 1.066e+04 acceptance rate: 0.007855272554153773
# i: 4400 mc loss: 1.066e+04 loss: 1.066e+04 acceptance rate: 0.0081799591002045
# i: 4600 mc loss: 1.066e+04 loss: 1.066e+04 acceptance rate: 0.008041730058682896
# i: 4800 mc loss: 1.066e+04 loss: 1.066e+04 acceptance rate: 0.007915017704644865
# i: 5000 mc loss: 1.066e+04 loss: 1.066e+04 acceptance rate: 0.007798440311937612
# i: 5200 mc loss: 1.066e+04 loss: 1.066e+04 acceptance rate: 0.008267640838300326
# i: 5400 mc loss: 1.066e+04 loss: 1.066e+04 acceptance rate: 0.008331790409183484

# %%
#9197s for 20*1000 iters

# %%
bed1 = np.loadtxt('Totten_sgs1_bed_1000.txt')
plt.pcolormesh(xx,yy,bed1,vmax=2000,vmin=-2500)
plt.axis('scaled')
plt.colorbar()
plt.xlabel('x (m)')
plt.ylabel('y (m)')
# Out:
# Text(0, 0.5, 'y (m)')

# %%
bed2 = np.loadtxt('Totten_sgs1_bed_19000.txt')
plt.pcolormesh(xx,yy,bed2,vmax=2000,vmin=-2500)
plt.axis('scaled')
plt.colorbar()
plt.xlabel('x (m)')
plt.ylabel('y (m)')
# Out:
# Text(0, 0.5, 'y (m)')

# %%
plt.pcolormesh(xx,yy,bed2-bed1, cmap='RdBu',vmax=200,vmin=-200)
plt.axis('scaled')
plt.colorbar()
plt.xlabel('x (m)')
plt.ylabel('y (m)')
# Out:
# Text(0, 0.5, 'y (m)')

# %%
plt.pcolormesh(xx,yy,bed2-bed1>1)
plt.axis('scaled')
plt.colorbar()
plt.xlabel('x (m)')
plt.ylabel('y (m)')
# Out:
# Text(0, 0.5, 'y (m)')

# %%
bed2 = np.loadtxt('Totten_sgs1_bed_19000.txt')
plt.pcolormesh(xx,yy,bed2 - cond_bed,vmax=1,vmin=-1,cmap='RdBu')
plt.axis('scaled')
plt.colorbar()
plt.xlabel('x (m)')
plt.ylabel('y (m)')
# Out:
# Text(0, 0.5, 'y (m)')
